# %% [markdown]
# # Natural Language Geneartion
# ## (Character - by - Character)
# Generate new Answer Cards using RNN

# %% [markdown]
# #### Pre-processing
# Length of vocab: 1465
# Length of first line: 5

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import silhouette_score
from sklearn import metrics

import numpy as np
import random
import pandas as pd
import os
import pickle

# %%
os.chdir('/Users/bellepeng/Desktop/Metis/Projects/NLP_CardsAgainstHumanity/data')

# %%
# file = unidecode.unidecode(open('CAH_predicted_answers.txt').read())
with open('CAH_predicted_answers.txt', 'r') as text:
    file = text.read()#.split('\n')

file = file.replace('\n', ' ')
file = file.replace("\'", "'")
file = file.replace("<br>", " ")
file
# Out:
# 'Why can\'t I sleep at night? Salsa Night at Dave\'s Cantina.   Why can\'t I sleep at night? Turning 32.   Why can\'t I sleep at night? Wearing glasses and sounding smart.   Why can\'t I sleep at night? Shitting all over the floor like a bad, bad girl.   Why can\'t I sleep at night? The passage of time.   I got 99 problems but _ ain\'t one. Intimacy problems.   I got 99 problems but _ ain\'t one. A web of lies.   I got 99 problems but _ ain\'t one. The Google.   I got 99 problems but _ ain\'t one. A sea of troubles.   I got 99 problems but _ ain\'t one. A rival dojo.   What\'s a girl\'s best friend? Bees?   What\'s a girl\'s best friend? Happy daddies with happy sandals.   What\'s a girl\'s best friend? Opening your mouth to talk and a big penis fops out.   What\'s a girl\'s best friend? Seeing things from Hitler\'s perspective   What\'s a girl\'s best friend? A medium horchata.   What\'s that smell? Bees?   What\'s that smell? Putting an entire peanut butter and jelly sandwich into the VCR.   What\'s that smell? No longer finding any Cards Against Humanity card funny.   What\'s that smell? Homeless people.   What\'s that smell? Genghis Khan\'s DNA.   This is the way the world ends / This is the way the world ends / Not with a bang but with _. Not contributing to society in any meaningful way.   This is the way the world ends / This is the way the world ends / Not with a bang but with _. Sexy pillow fights.   This is the way the world ends / This is the way the world ends / Not with a bang but with _. A subscription to Men\'s Fitness.   This is the way the world ends / This is the way the world ends / Not with a bang but with _. Getting high with mom.   This is the way the world ends / This is the way the world ends / Not with a bang but with _. One trillion dollars.   What is Batman\'s guilty pleasure? A subscription to Men\'s Fitness.   What is Batman\'s guilty pleasure? Growing up chained to a radiator in perpetual darkness.   What is Batman\'s guilty pleasure? The swim team, all at once.   What is Batman\'s guilty pleasure? Having an awesome time drinking and driving.   What is Batman\'s guilty pleasure? Alcoholism.   TSA guidelines now prohibit _ on airplanes. A bass drop so huge it tears the starry vault asunder to reveal the face of God.   TSA guidelines now prohibit _ on airplanes. Panty raids.   TSA guidelines now prohibit _ on airplanes. A sad fat dragon with no friends.   TSA guidelines now prohibit _ on airplanes. The entire Mormon Tabernacle Choir.   TSA guidelines now prohibit _ on airplanes. Trees.   What ended my last relationship? Bees?   What ended my last relationship? Getting naked too soon.   What ended my last relationship? Huge big balls full of jizz.   What ended my last relationship? Taking off your shirt.   What ended my last relationship? Libertarians.   MTV\'s new reality show features eight washed-up celebrities living with _. Rehab.   MTV\'s new reality show features eight washed-up celebrities living with _. Misogyny.   MTV\'s new reality show features eight washed-up celebrities living with _. Twenty bucks.   MTV\'s new reality show features eight washed-up celebrities living with _. The passage of time.   MTV\'s new reality show features eight washed-up celebrities living with _. Nothing.   I drink to forget _. Dick fingers.   I drink to forget _. Grammar nazis who are also regular Nazis.   I drink to forget _. Mufasa\'s death scene.   I drink to forget _. A bag of magic beans.   I drink to forget _. The Three-Fifths compromise.   I\'m sorry, Professor, but I couldn\'t complete my homework because of _. Homework.   I\'m sorry, Professor, but I couldn\'t complete my homework because of _. 10 football players with erections barreling towards you at full speed.   I\'m sorry, Professor, but I couldn\'t complete my homework because of _. Forgetting grandma\'s first name.   I\'m sorry, Professor, but I couldn\'t complete my homework because of _. Period poops.   I\'m sorry, Professor, but I couldn\'t ...

# %% [markdown]
# ### Model

# %%
# Read in text and change unicode characters to ASCII
import unidecode
import string
import random
import re

all_characters = string.printable
n_characters = len(all_characters)

file_len = len(file)
print(f'file_len = {file_len}')
# Out:
# file_len = 128877

# %%
chunk_len = 100

def random_chunk():
    start_index = random.randint(0, file_len - chunk_len)
    end_index = start_index + chunk_len + 1
    return file[start_index:end_index]

print(random_chunk())
# Out:
# 10, you can save this child from _. Having an awesome time drinking and driving.   With a one-time gi

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F

class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, n_layers=1):
        super(RNN, self).__init__()
        self.input_size = input_size #chunks
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        
        self.encoder = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers)
        self.decoder = nn.Linear(hidden_size, output_size)
        
    def forward(self, input, hidden):
        output = self.encoder(input.view(1, -1))
        output, hidden = self.gru(output.view(1, 1, -1), hidden)
        output = self.decoder(output.view(1, -1))
        
        return output, hidden
    
    def init_hidden(self):
        return Variable(torch.randn(self.n_layers, 1, self.hidden_size))

# %%
def char2tensor(string):
    tensor = torch.zeros(len(string)).long()
    for char in range(len(string)):
        if string[char] in all_characters:
            tensor[char] = all_characters.index(string[char])
        else:
            tensor[char] = 94 #predict space if character unknown
        
    return Variable(tensor)

# Let's see it in action.
# print(string.printable)
# print(char2tensor(all_characters))

# %%
def random_training_set():
    chunk = random_chunk()
    inp = char2tensor(chunk[:-1])
    target = char2tensor(chunk[1:])
    return inp, target

# %%
def evaluate(model, prime_str='A', predict_len=100, temperature=0.8):
    
    hidden = model.init_hidden()
    prime_input = char2tensor(prime_str)
    predicted = prime_str
    
    # use priming string to build up hidden state
    
    for p in range(len(prime_str) - 1):
        _, hidden = model(prime_input[p], hidden)
    inp = prime_input[-1]
    
    for p in range(predict_len):
        output, hidden = model(inp, hidden)
        
        # Sample from the network as a multinomial distribution
        output_dist = output.data.view(-1).div(temperature).exp()
        top_i = torch.multinomial(output_dist, 1)[0]
        
        # Add predicted character to string and use as next input
        predicted_char = all_characters[top_i]
        predicted += predicted_char
        inp = char2tensor(predicted_char)
        
    return predicted

# %% [markdown]
# #### Training

# %%
# helper function
import time, math

def time_since(since):
    s = time.time() - since
    m = math.floor(s/60)
    s -= m*60
    return '%dm %ds' % (m, s)

# %%
# The actual training part
def train(inp, target):
    hidden = model.init_hidden()
    model.zero_grad()
    loss = 0

    for char in range(chunk_len):
        output, hidden = model(inp[char], hidden)
        loss += criterion(output, target[char].unsqueeze(0))

    loss.backward()
    model_optimizer.step()

    return loss.data.item() / chunk_len

# %%
# parameters
n_epochs = 5000
print_every = 100
plot_every = 20
hidden_size = 256
n_layers = 2
learning_rate = 0.001

# model declaration
model = RNN(n_characters, hidden_size, n_characters, n_layers)
model_optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

start = time.time()
all_losses = []
loss_avg = 0

for epoch in range(1, n_epochs + 1):
    loss = train(*random_training_set())       
    loss_avg += loss

    if epoch % print_every == 0:
        print('[%s (%d %d%%) %.4f]' % (time_since(start), epoch, epoch / n_epochs * 100, loss))
        print(evaluate(model, 'A ', 100), '\n')

    if epoch % plot_every == 0:
        all_losses.append(loss_avg / plot_every)
        loss_avg = 0
# Out:
#  34s (100 2%) 2.7323]
# A hdenes babdis tice on doc feng ther th orrryed cin set roL nin less din the mighed fin poting an riw
#
#  3s (200 4%) 2.2596]
# A _ mon tOitis cou ing toe is Godremrulsenit aly _ whecot the Is wolleral.    Whan od sun ing in a to
#
#  32s (300 6%) 2.0928]
# A Vublring arot.     Ore, Avery thie.   The gorl, bering, she fawill a be to Anta has tak ing, to _. H
#
#  6s (400 8%) 2.0371]
# A sime sto fat bet _le.   Oon _.   Petts in seras Has opep oul so a cont at ove _. The leatfer, helat
#
#  38s (500 10%) 2.3069]
# A the be new supplooper that you the expentle.   You the coliest your but thing.   A langemy Wromanal
#
#  12s (600 12%) 1.8739]
# A deataened a dican the Up of be pury froot for we will like monting tell of hef tour the perprood of
#
#  49s (700 14%) 2.0160]
# A now ba for kick me Pore.   A brovel braging, _, a ss.   What gring all in't but enofe.   A pairs.
#
#  20s (800 16%) 2.0002]
# A Might cashar's never momy ages we mongen olemory _. The the dustible out of _. The gerdreg; fillly b
#
#  52s (900 18%) 2.0262]
# A colvident pasffor _ and unconse the gods in to the call ubints a'ving tremome prick friends? Iat you
#
#  27s (1000 20%) 2.1689]
# A watich _. Homerien lions an now _. Cork in _. Sexiecouphersing this is _. Shai's heroue my so sir my
#
#  13s (1100 22%) 2.0439]
# A Flastay for would I kids for my we for good begontigy really really will now was the found you ond f
#
#  59s (1200 24%) 2.2249]
# A sow subeceed is _: Monner $1,00: Hooperinal pay wart our want weull you're don't or gast regure a ho
#
#  54s (1300 26%) 2.0399]
# A good and a sueing goover. Scially. The Gord, you me do holine. The with _, by a slaughter? Eatas ims
#
#  55s (1400 28%) 1.7683]
# A Ands am nirnew all be _. A parting and _. A shitting.   Heartmos by _. A scaught in a pace.   Make i
#
#  38s (1500 30%) 1.5225]
# A gilling must is distore of that dirsturbation.   Why addy,  I killed along this imerson steer for _.
#
#  20s (1600 32%) 1.7181]
# A dinterested _. Sexuinteron, things be a to _. An over.   Ast at the Lody by at _. A moother. The tho
#
#  1s (1700 34%) 1.2571]
# A can asteases can hands /Barack Eass and but is mays and me it one for the proppainical purgans.   Wh
#
#  42s (1800 36%) 1.4013]
# A What's the I#II!   I'm you can't can't care the whe would to _. An eliminat friend? A bassureghy bro
#
#  22s (1900 38%) 1.4870]
# A broges.   What you'rreg Being the duck fuch Beer hands / This you have the chupchim.   Havidenty Bet
#
#  1s (2000 40%) 0.9745]
# A smottells to Haduin.   The Card fwaw to _. Sfitic, but a buy _ by this cove for _. 8eartide's bouch.
#
#  40s (2100 42%) 1.3319]
# A Vasicaned Lading in the pirt.   "I make that my some to a grage, my looked the has voiniona having i
#
#  24s (2200 44%) 1.2842]
# A Chocaney.   When hew Vid iney to _. Sexualy pleasute _. Chine West heer a sesfetime? A sfine for _.
#
#  8s (2300 46%) 1.1378]
# A   I is the me tours officuremore, An at remonive be the have god dist for _. God. I she's shit onroo
#
#  54s (2400 48%) 1.4082]
# A manty reall there Intain? Lething states of God. I small-want terr. Meanity plays that never be who
#
#  38s (2500 50%) 1.0265]
# A Cheney for _. Rad. Ebody is _. You'd one of a Repiccines.   Why can' that I star ow _! Letting a lit
#
#  28s (2600 52%) 1.0273]
# A morsing a little big things in first of _. Passive Cazbaing? The Mrife discover for America's been a
#
#  14s (2700 54%) 1.7440]
# A bring.   Art is _. Smelity Jang a feel friend.   Wes Kan of Goldstep by _. Go-dinner of gift.</br>-
#
#  59s (2800 56%) 1.2951]
# A completes Picture?   Daddy, I kid, we orginated _ in the right, but move. A bucket power back in a r
#
#  43s (2900 57%) 1.5217]
# A viging this is _. How stuffy tiny public likes.   In his it the am I come to ernm with _. The United
#
#  28s (3000 60%) 0.9892]
# A colleter's beginning right develomed _ has just _ conting to have become _! Montanimen pictures. <i>
#
#  13s (3100 62%) 1.2602]
# A could do will land to interation's be enough for holl of _. An always be the sames.   TSA good all n
#
#  58s (3200 64%) 0.7579]
# A secretting to grandma find of daddy in a for _. Poorl-most penis of burger of the monthfied commerca
#
#  42s (3300 66%) 0.9886]
# A but _. A man is _. The tiny, rand being the world ended my boefts and ruined by _. Sexy penetrations
#
#  31s (3400 68%) 1.0903]
# A guys for my famie.   What does it courner? A guilling a maybory.   War III will full of _. An old, b
#
#  19s (3500 70%) 1.1274]
# A #mazon with my collul!   Why am I love _! Facism once world is a crime.   I've mealing off a toward
#
#  7s (3600 72%) 0.9392]
# A Baking up anyone. White permanship.   Advante with _. The distann balls.   _ male with _. Making a m
#
#  51s (3700 74%) 0.8480]
# A create there at a trumpes.   The Anderson's newest.   Oh not know who octuble to covetome that you c
#
#  36s (3800 76%) 0.5262]
# A guident me without _. Sepican With _. Perfection of _. Pretty States, I will be four most for _. A c
#
#  20s (3900 78%) 0.8903]
# A bles.   What's the month scounting die. Roman with molk am I coll I got _. A bunch out famous horrif
#
#  8s (4000 80%) 0.9481]
# A   One monthat destroyer for _. Swift that Vladich on his is a discotus.   What has found _ = been so
#
#  54s (4100 82%) 1.0020]
# A God.   I'll the meries right, I killed _. Perfect peconce with _. Getting all the Thess began with _
#
#  40s (4200 84%) 1.0729]
# A tells in Richall eyess.   What's the boys actered every first stare of ewesons.   What don't stare o
#
#  27s (4300 86%) 1.5291]
# A Plother. Actic Chanied Stance.   In the next try _. An allow stupping.   But of the Academy Againt p
#
#  15s (4400 88%) 0.9193]
# A way the chrobit _ out of a been mome.   In the beginning, love now interviel, scroupted the oright.
#
#  8s (4500 90%) 0.7926]
# A falling virto grummal night.   And the Academy for hand, which one would get rid by _. Poor life.
#
#  59s (4600 92%) 1.1569]
# A was the negxing about _, and I'll show you _. Friday.   What I am a firm nothing.   The Believe Bara
#
#  48s (4700 94%) 0.8372]
# A midge.   Errbody in the way think about _. Being problems.   That's you can't you won't belies of _.
#
#  36s (4800 96%) 0.7998]
# A   In his new action of complete was the movie of it has discovers all elite a trap! Gary than we nee
#
#  20s (4900 98%) 0.8150]
# A man's auted birds, purple, or human.   What human ready fails tears in the who could like _. Mufathe
#
#  2s (5000 100%) 0.9351]
# A gassunds of _. Putting of of humen.   I learns awkward for _ goes to _. Grave seat.   What's than wi

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

plt.figure(dpi=150)
plt.plot(all_losses)
plt.title('Loss over Time', size=25)
plt.tick_params(axis='both', labelsize=15)
plt.xlabel('Every 20 Epochs', fontsize=15)
plt.ylabel('Neg Log Likelihood Loss', fontsize=15)
# Out:
# Text(0,0.5,'Neg Log Likelihood Loss')

# %%
# Evaluate Trump
print(evaluate(model, "kdogliuo889", predict_len=50, temperature=0.5))
# Out:
# kdogliuo889.   Do you lack energy? Does it some stuffed with

# %%
# import os
# os.chdir('/Users/bellepeng/Desktop/Metis/Projects/NLP_CardsAgainstHumanity/data')
# torch.save(model, 'model_nlg_2.pt')
# Out:
# /anaconda3/lib/python3.6/site-packages/torch/serialization.py:241: UserWarning: Couldn't retrieve source code for container of type RNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
# model2 = torch.load('model_nlg_2.pt')
